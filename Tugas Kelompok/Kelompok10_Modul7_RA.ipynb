# %%
import pandas as pd

df = pd.read_csv('/content/911_Calls_for_Service_(Last_30_Days).csv')

# %%
import csv
from functools import reduce

data = []
with open('/content/911_Calls_for_Service_(Last_30_Days).csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)

filtered_data = list(filter(lambda x: x['zip_code'] != '' and x['neighborhood'] != '', data))

numeric_data = [{'total_response_time': float(row['totalresponsetime']) if row['totalresponsetime'] is not None and row['totalresponsetime'] != '' else 0,
                 'dispatch_time': float(row['dispatchtime']) if row['dispatchtime'] is not None and row['dispatchtime'] != '' else 0,
                 'total_time': float(row['totaltime']) if row['totaltime'] is not None and row['totaltime'] != '' else 0} for row in filtered_data]

total_response_time = reduce(lambda x, y: x + y['total_response_time'], numeric_data, 0)
total_dispatch_time = reduce(lambda x, y: x + y['dispatch_time'], numeric_data, 0)
total_total_time = reduce(lambda x, y: x + y['total_time'], numeric_data, 0)

average_response_time = total_response_time / len(numeric_data)
average_dispatch_time = total_dispatch_time / len(numeric_data)
average_total_time = total_total_time / len(numeric_data)

print("Total rata-rata waktu respons:", average_response_time)
print("Total rata-rata waktu pengiriman:", average_dispatch_time)
print("Total rata-rata waktu keseluruhan:", average_total_time)
# Out:
# Total rata-rata waktu respons: 9.40852188883424
# Total rata-rata waktu pengiriman: 5.641662567634036
# Total rata-rata waktu keseluruhan: 31.09880718150527

# %%
from functools import reduce

neighborhood_data = {}
for row in filtered_data:
    if row['neighborhood'] not in neighborhood_data:
        neighborhood_data[row['neighborhood']] = []
    neighborhood_data[row['neighborhood']].append(row)

neighborhood_stats = []
for neighborhood, incidents in neighborhood_data.items():
    numeric_data = [{'total_response_time': float(row['totalresponsetime']) if row['totalresponsetime'] is not None and row['totalresponsetime'] != '' else 0,
                 'dispatch_time': float(row['dispatchtime']) if row['dispatchtime'] is not None and row['dispatchtime'] != '' else 0,
                 'total_time': float(row['totaltime']) if row['totaltime'] is not None and row['totaltime'] != '' else 0} for row in incidents]

    total_response_time = reduce(lambda x, y: x + y['total_response_time'], numeric_data, 0)
    total_dispatch_time = reduce(lambda x, y: x + y['dispatch_time'], numeric_data, 0)
    total_total_time = reduce(lambda x, y: x + y['total_time'], numeric_data, 0)

    average_response_time = total_response_time / len(numeric_data)
    average_dispatch_time = total_dispatch_time / len(numeric_data)
    average_total_time = total_total_time / len(numeric_data)

    neighborhood_stats.append({
        'neighborhood': neighborhood,
        'average_response_time': average_response_time,
        'average_dispatch_time': average_dispatch_time,
        'average_total_time': average_total_time
    })

total_numeric_data = [{'total_response_time': float(row['totalresponsetime']) if row['totalresponsetime'] is not None and row['totalresponsetime'] != '' else 0,
                       'dispatch_time': float(row['dispatchtime']) if row['dispatchtime'] is not None and row['dispatchtime'] != '' else 0,
                       'total_time': float(row['totaltime']) if row['totaltime'] is not None and row['totaltime'] != '' else 0} for row in filtered_data]

total_response_time_detroit = reduce(lambda x, y: x + y['total_response_time'], total_numeric_data, 0)
total_dispatch_time_detroit = reduce(lambda x, y: x + y['dispatch_time'], total_numeric_data, 0)
total_total_time_detroit = reduce(lambda x, y: x + y['total_time'], total_numeric_data, 0)

average_response_time_detroit = total_response_time_detroit / len(total_numeric_data)
average_dispatch_time_detroit = total_dispatch_time_detroit / len(total_numeric_data)
average_total_time_detroit = total_total_time_detroit / len(total_numeric_data)

neighborhood_stats.append({
    'neighborhood': 'All Detroit',
    'average_response_time': average_response_time_detroit,
    'average_dispatch_time': average_dispatch_time_detroit,
    'average_total_time': average_total_time_detroit
})

for stats in neighborhood_stats:
    print("Lingkungan:", stats['neighborhood'])
    print("Rata-rata waktu respon :", stats['average_response_time'])
    print("Rata-rata waktu pengiriman:", stats['average_dispatch_time'])
    print("Total waktu dalam rata-rata:", stats['average_total_time'])
# Out:
# Lingkungan: Eden Gardens
# Rata-rata waktu respon : 13.149999999999997
# Rata-rata waktu pengiriman: 9.020833333333334
# Total waktu dalam rata-rata: 43.59583333333334
# Lingkungan: Buffalo Charles
# Rata-rata waktu respon : 8.08
# Rata-rata waktu pengiriman: 5.856666666666667
# Total waktu dalam rata-rata: 30.676666666666673
# Lingkungan: New Center
# Rata-rata waktu respon : 0.5586956521739129
# Rata-rata waktu pengiriman: 0.10869565217391307
# Total waktu dalam rata-rata: 14.825000000000001
# Lingkungan: O'Hair Park
# Rata-rata waktu respon : 23.16842105263158
# Rata-rata waktu pengiriman: 16.978947368421053
# Total waktu dalam rata-rata: 48.92368421052631
# Lingkungan: Miller Grove
# Rata-rata waktu respon : 8.152941176470588
# Rata-rata waktu pengiriman: 4.3882352941176475
# Total waktu dalam rata-rata: 48.09411764705882
# Lingkungan: Elmwood Park
# Rata-rata waktu respon : 13.394736842105262
# Rata-rata waktu pengiriman: 9.176315789473685
# Total waktu dalam rata-rata: 32.415789473684214
# Lingkungan: Downtown
# Rata-rata waktu respon : 3.8100790513833993
# Rata-rata waktu pengiriman: 2.1434782608695655
# Total waktu dalam rata-rata: 20.63537549407116
# Lingkungan: Warrendale
# Rata-rata waktu respon : 18.43740458015267
# Rata-rata waktu pengiriman: 11.05954198473282
# Total waktu dalam rata-rata: 43.949618320610675
# Lingkungan: Palmer Park
# Rata-rata waktu respon : 12.473076923076926
# Rata-rata waktu pengiriman: 6.130769230769232
# Total waktu dalam rata-rata: 32.11923076923077
# Lingkungan: Brightmoor
# Rata-rata waktu respon : 15.512195121951214
# Rata-rata waktu pengiriman: 9.595934959349592
# Total waktu dalam rata-rata: 37.8552845528455
# Lingkungan: McDougall-Hunt
# Rata-rata waktu respon : 8.823076923076924
# Rata-rata waktu pengiriman: 4.7384615384615385
# Total waktu dalam rata-rata: 23.582692307692312
# Lingkungan: Detroit Golf
# Rata-rata waktu respon : 19.099999999999998
# Rata-rata waktu pengiriman: -0.03333333333333333
# Total waktu dalam rata-rata: 26.233333333333334
# Lingkungan: Central Southwest
# Rata-rata waktu respon : 5.5048543689320395
# Rata-rata waktu pengiriman: 2.175728155339806
# Total waktu dalam rata-rata: 22.198058252427185
# Lingkungan: Eastern Market
# Rata-rata waktu respon : 0.6043478260869566
# Rata-rata waktu pengiriman: 0.286231884057971
# Total waktu dalam rata-rata: 18.2695652173913
# Lingkungan: Davison
# Rata-rata waktu respon : 3.6648148148148154
# Rata-rata waktu pengiriman: 1.2314814814814818
# Total waktu dalam rata-rata: 15.968518518518518
# Lingkungan: Schulze
# Rata-rata waktu respon : 15.972857142857148
# Rata-rata waktu pengiriman: 11.927142857142856
# Total waktu dalam rata-rata: 47.19285714285714
# Lingkungan: Grand River-I96
# Rata-rata waktu respon : 9.365714285714285
# Rata-rata waktu pengiriman: 6.936190476190475
# Total waktu dalam rata-rata: 27.81238095238096
# Lingkungan: Oakman Blvd Community
# Rata-rata waktu respon : 13.339393939393943
# Rata-rata waktu pengiriman: 7.048484848484848
# Total waktu dalam rata-rata: 45.32828282828284
# Lingkungan: Boynton
# Rata-rata waktu respon : 9.238333333333333
# Rata-rata waktu pengiriman: 5.965
# Total waktu dalam rata-rata: 25.65666666666666
# Lingkungan: Farwell
# Rata-rata waktu respon : 1.423529411764706
# Rata-rata waktu pengiriman: 0.4470588235294117
# Total waktu dalam rata-rata: 19.670588235294115
# Lingkungan: Cornerstone Village
# Rata-rata waktu respon : 13.785897435897436
# Rata-rata waktu pengiriman: 7.410256410256409
# Total waktu dalam rata-rata: 45.75769230769231
# Lingkungan: Bethune Community
# Rata-rata waktu respon : 17.496460176991153
# Rata-rata waktu pengiriman: 8.840707964601773
# Total waktu dalam rata-rata: 38.10530973451326
# Lingkungan: Russell Woods
# Rata-rata waktu respon : 13.054999999999998
# Rata-rata waktu pengiriman: 8.79
# Total waktu dalam rata-rata: 20.529999999999994
# Lingkungan: Gratiot-Findlay
# Rata-rata waktu respon : 0.6699029126213593
# Rata-rata waktu pengiriman: 0.20194174757281555
# Total waktu dalam rata-rata: 8.637864077669905
# Lingkungan: Gratiot Town/Ketterring
# Rata-rata waktu respon : 12.067857142857141
# Rata-rata waktu pengiriman: 7.410714285714286
# Total waktu dalam rata-rata: 74.02142857142857
# Lingkungan: Grandmont #1
# Rata-rata waktu respon : 20.508333333333333
# Rata-rata waktu pengiriman: 13.083333333333334
# Total waktu dalam rata-rata: 32.9
# Lingkungan: Greenfield
# Rata-rata waktu respon : 13.013114754098362
# Rata-rata waktu pengiriman: 7.301639344262294
# Total waktu dalam rata-rata: 34.67213114754098
# Lingkungan: Aviation Sub
# Rata-rata waktu respon : 19.06896551724138
# Rata-rata waktu pengiriman: 13.017241379310347
# Total waktu dalam rata-rata: 48.75517241379309
# Lingkungan: Chandler Park
# Rata-rata waktu respon : 7.674074074074075
# Rata-rata waktu pengiriman: 2.5444444444444447
# Total waktu dalam rata-rata: 28.892592592592596
# Lingkungan: Rosedale Park
# Rata-rata waktu respon : 12.771428571428574
# Rata-rata waktu pengiriman: 8.652380952380952
# Total waktu dalam rata-rata: 27.30952380952381
# Lingkungan: Greektown
# Rata-rata waktu respon : 1.4824561403508771
# Rata-rata waktu pengiriman: 0.14298245614035088
# Total waktu dalam rata-rata: 18.247368421052634
# Lingkungan: Warren Ave Community
# Rata-rata waktu respon : 11.549999999999999
# Rata-rata waktu pengiriman: 7.834374999999999
# Total waktu dalam rata-rata: 29.83645833333334
# Lingkungan: McNichols Evergreen
# Rata-rata waktu respon : 5.43125
# Rata-rata waktu pengiriman: 3.81875
# Total waktu dalam rata-rata: 24.9375
# Lingkungan: Hubbard Farms
# Rata-rata waktu respon : 3.2555555555555555
# Rata-rata waktu pengiriman: 0.9333333333333333
# Total waktu dalam rata-rata: 12.233333333333333
# Lingkungan: West End
# Rata-rata waktu respon : 12.696551724137931
# Rata-rata waktu pengiriman: 7.689655172413793
# Total waktu dalam rata-rata: 38.10000000000001
# Lingkungan: Campau/Banglatown
# Rata-rata waktu respon : 7.433333333333334
# Rata-rata waktu pengiriman: 2.1333333333333333
# Total waktu dalam rata-rata: 31.95833333333334
# Lingkungan: Krainz Woods
# Rata-rata waktu respon : 13.904761904761905
# Rata-rata waktu pengiriman: 9.114285714285716
# Total waktu dalam rata-rata: 38.61904761904762
# Lingkungan: Barton-McFarland
# Rata-rata waktu respon : 28.87096774193548
# Rata-rata waktu pengiriman: 18.49838709677419
# Total waktu dalam rata-rata: 67.65483870967743
# Lingkungan: Woodbridge
# Rata-rata waktu respon : 3.1999999999999997
# Rata-rata waktu pengiriman: 0.7108695652173914
# Total waktu dalam rata-rata: 34.56304347826087
# Lingkungan: Five Points
# Rata-rata waktu respon : 10.292857142857143
# Rata-rata waktu pengiriman: 5.821428571428571
# Total waktu dalam rata-rata: 38.79285714285714
# Lingkungan: Petoskey-Otsego
# Rata-rata waktu respon : 13.558823529411763
# Rata-rata waktu pengiriman: 7.835294117647057
# Total waktu dalam rata-rata: 27.69411764705882
# Lingkungan: Minock Park
# Rata-rata waktu respon : 17.287499999999998
# Rata-rata waktu pengiriman: 7.1375
# Total waktu dalam rata-rata: 59.36250000000001
# Lingkungan: Pulaski
# Rata-rata waktu respon : 17.294000000000004
# Rata-rata waktu pengiriman: 9.033999999999999
# Total waktu dalam rata-rata: 39.21599999999999
# Lingkungan: Forest Park
# Rata-rata waktu respon : 7.92
# Rata-rata waktu pengiriman: 2.4999999999999996
# Total waktu dalam rata-rata: 36.45
# Lingkungan: Cadillac Community
# Rata-rata waktu respon : 27.522222222222222
# Rata-rata waktu pengiriman: 21.488888888888887
# Total waktu dalam rata-rata: 51.711111111111116
# Lingkungan: Conner Creek
# Rata-rata waktu respon : 12.333333333333334
# Rata-rata waktu pengiriman: 7.287500000000001
# Total waktu dalam rata-rata: 47.931250000000006
# Lingkungan: Milwaukee Junction
# Rata-rata waktu respon : 3.1575757575757577
# Rata-rata waktu pengiriman: 0.5909090909090909
# Total waktu dalam rata-rata: 17.548484848484847
# Lingkungan: North End
# Rata-rata waktu respon : 9.493939393939392
# Rata-rata waktu pengiriman: 5.124242424242424
# Total waktu dalam rata-rata: 27.89090909090909
# Lingkungan: Nortown
# Rata-rata waktu respon : 7.296874999999999
# Rata-rata waktu pengiriman: 4.565625
# Total waktu dalam rata-rata: 22.073437500000004
# Lingkungan: Midtown
# Rata-rata waktu respon : 4.4621710526315805
# Rata-rata waktu pengiriman: 1.8148026315789467
# Total waktu dalam rata-rata: 29.381250000000033
# Lingkungan: Tech Town
# Rata-rata waktu respon : 3.6571428571428575
# Rata-rata waktu pengiriman: 0.2892857142857143
# Total waktu dalam rata-rata: 36.978571428571435
# Lingkungan: Grandmont
# Rata-rata waktu respon : 17.0
# Rata-rata waktu pengiriman: 11.585714285714285
# Total waktu dalam rata-rata: 28.87857142857143
# Lingkungan: North LaSalle
# Rata-rata waktu respon : 7.049999999999999
# Rata-rata waktu pengiriman: 0.8142857142857143
# Total waktu dalam rata-rata: 46.50714285714286
# Lingkungan: Pembroke
# Rata-rata waktu respon : 17.677777777777777
# Rata-rata waktu pengiriman: 7.2444444444444445
# Total waktu dalam rata-rata: 77.87777777777777
# Lingkungan: College Park
# Rata-rata waktu respon : 15.70923076923077
# Rata-rata waktu pengiriman: 11.592307692307692
# Total waktu dalam rata-rata: 38.16307692307692
# Lingkungan: Hubbell-Puritan
# Rata-rata waktu respon : 17.771428571428572
# Rata-rata waktu pengiriman: 9.70952380952381
# Total waktu dalam rata-rata: 57.26666666666667
# Lingkungan: We Care Community
# Rata-rata waktu respon : 14.205555555555556
# Rata-rata waktu pengiriman: 9.6
# Total waktu dalam rata-rata: 34.76666666666668
# Lingkungan: Indian Village
# Rata-rata waktu respon : 5.58
# Rata-rata waktu pengiriman: 0.06000000000000001
# Total waktu dalam rata-rata: 18.68
# Lingkungan: NW Goldberg
# Rata-rata waktu respon : 13.823529411764707
# Rata-rata waktu pengiriman: 7.858823529411764
# Total waktu dalam rata-rata: 40.94411764705882
# Lingkungan: Joy-Schaefer
# Rata-rata waktu respon : 20.469230769230766
# Rata-rata waktu pengiriman: 18.284615384615385
# Total waktu dalam rata-rata: 33.61538461538461
# Lingkungan: North Corktown
# Rata-rata waktu respon : 4.515625
# Rata-rata waktu pengiriman: 1.4312499999999997
# Total waktu dalam rata-rata: 45.240625
# Lingkungan: Core City
# Rata-rata waktu respon : 10.975
# Rata-rata waktu pengiriman: 7.716666666666665
# Total waktu dalam rata-rata: 24.875
# Lingkungan: West Side Industrial
# Rata-rata waktu respon : 7.5636363636363635
# Rata-rata waktu pengiriman: 1.9454545454545453
# Total waktu dalam rata-rata: 55.4
# Lingkungan: Franklin Park
# Rata-rata waktu respon : 5.243548387096774
# Rata-rata waktu pengiriman: 3.4028225806451626
# Total waktu dalam rata-rata: 20.96935483870968
# Lingkungan: Regent Park
# Rata-rata waktu respon : 7.840963855421685
# Rata-rata waktu pengiriman: 3.471084337349397
# Total waktu dalam rata-rata: 40.00722891566266
# Lingkungan: Delray
# Rata-rata waktu respon : 0.9424657534246577
# Rata-rata waktu pengiriman: 0.4424657534246575
# Total waktu dalam rata-rata: 13.954794520547946
# Lingkungan: Evergreen Lahser 7/8
# Rata-rata waktu respon : 13.852500000000001
# Rata-rata waktu pengiriman: 8.46
# Total waktu dalam rata-rata: 35.239999999999995
# Lingkungan: Westwood Park
# Rata-rata waktu respon : 20.015384615384615
# Rata-rata waktu pengiriman: 15.176923076923078
# Total waktu dalam rata-rata: 29.430769230769233
# Lingkungan: Conant Gardens
# Rata-rata waktu respon : 3.4642857142857144
# Rata-rata waktu pengiriman: 2.0714285714285716
# Total waktu dalam rata-rata: 12.942857142857141
# Lingkungan: Castle Rouge
# Rata-rata waktu respon : 17.575000000000003
# Rata-rata waktu pengiriman: 5.75
# Total waktu dalam rata-rata: 29.025
# Lingkungan: Airport Sub
# Rata-rata waktu respon : 12.305797101449274
# Rata-rata waktu pengiriman: 7.563768115942029
# Total waktu dalam rata-rata: 36.49999999999999
# Lingkungan: Riverbend
# Rata-rata waktu respon : 3.3227272727272728
# Rata-rata waktu pengiriman: 1.4833333333333334
# Total waktu dalam rata-rata: 16.309090909090912
# Lingkungan: The Eye
# Rata-rata waktu respon : 15.258823529411764
# Rata-rata waktu pengiriman: 10.988235294117645
# Total waktu dalam rata-rata: 31.9764705882353
# Lingkungan: Grant
# Rata-rata waktu respon : 0.20842105263157892
# Rata-rata waktu pengiriman: -0.009473684210526315
# Total waktu dalam rata-rata: 8.810526315789476
# Lingkungan: Evergreen-Outer Drive
# Rata-rata waktu respon : 6.447457627118645
# Rata-rata waktu pengiriman: 1.8644067796610169
# Total waktu dalam rata-rata: 20.845762711864406
# Lingkungan: Ravendale
# Rata-rata waktu respon : 6.835000000000001
# Rata-rata waktu pengiriman: 1.41
# Total waktu dalam rata-rata: 23.259999999999998
# Lingkungan: Joy Community
# Rata-rata waktu respon : 12.42
# Rata-rata waktu pengiriman: 9.610000000000003
# Total waktu dalam rata-rata: 36.0775
# Lingkungan: Corktown
# Rata-rata waktu respon : 8.12888888888889
# Rata-rata waktu pengiriman: 3.408888888888889
# Total waktu dalam rata-rata: 34.193333333333335
# Lingkungan: Wayne State
# Rata-rata waktu respon : 1.7715189873417723
# Rata-rata waktu pengiriman: 0.47974683544303787
# Total waktu dalam rata-rata: 32.08227848101266
# Lingkungan: Belmont
# Rata-rata waktu respon : 4.445454545454545
# Rata-rata waktu pengiriman: 1.8272727272727272
# Total waktu dalam rata-rata: 17.772727272727273
# Lingkungan: North Rosedale Park
# Rata-rata waktu respon : 7.040740740740739
# Rata-rata waktu pengiriman: 4.033333333333333
# Total waktu dalam rata-rata: 32.303703703703704
# Lingkungan: Oak Grove
# Rata-rata waktu respon : 2.9584158415841584
# Rata-rata waktu pengiriman: 1.7069306930693067
# Total waktu dalam rata-rata: 15.565346534653472
# Lingkungan: Schoolcraft Southfield
# Rata-rata waktu respon : 8.464814814814815
# Rata-rata waktu pengiriman: 5.809259259259259
# Total waktu dalam rata-rata: 32.803703703703704
# Lingkungan: Crary/St Marys
# Rata-rata waktu respon : 8.944642857142856
# Rata-rata waktu pengiriman: 4.282142857142857
# Total waktu dalam rata-rata: 39.30178571428571
# Lingkungan: Mount Olivet
# Rata-rata waktu respon : 7.697058823529411
# Rata-rata waktu pengiriman: 4.442647058823529
# Total waktu dalam rata-rata: 19.257352941176475
# Lingkungan: Nardin Park
# Rata-rata waktu respon : 3.827777777777778
# Rata-rata waktu pengiriman: 1.9981481481481478
# Total waktu dalam rata-rata: 18.726851851851844
# Lingkungan: Pershing
# Rata-rata waktu respon : 8.06111111111111
# Rata-rata waktu pengiriman: 5.694444444444444
# Total waktu dalam rata-rata: 34.36666666666666
# Lingkungan: Palmer Woods
# Rata-rata waktu respon : 1.3413793103448277
# Rata-rata waktu pengiriman: 0.31149425287356325
# Total waktu dalam rata-rata: 17.567816091954022
# Lingkungan: Islandview
# Rata-rata waktu respon : 12.714
# Rata-rata waktu pengiriman: 7.865999999999999
# Total waktu dalam rata-rata: 41.08599999999999
# Lingkungan: Piety Hill
# Rata-rata waktu respon : 15.4
# Rata-rata waktu pengiriman: 12.592857142857145
# Total waktu dalam rata-rata: 36.46428571428571
# Lingkungan: Nolan
# Rata-rata waktu respon : 6.35808383233533
# Rata-rata waktu pengiriman: 3.838922155688622
# Total waktu dalam rata-rata: 18.389221556886223
# Lingkungan: Far West Detroit
# Rata-rata waktu respon : 21.342857142857145
# Rata-rata waktu pengiriman: 13.147619047619049
# Total waktu dalam rata-rata: 49.647619047619045
# Lingkungan: Claytown
# Rata-rata waktu respon : 14.837113402061858
# Rata-rata waktu pengiriman: 8.510309278350517
# Total waktu dalam rata-rata: 36.09587628865979
# Lingkungan: Dexter-Linwood
# Rata-rata waktu respon : 14.703529411764707
# Rata-rata waktu pengiriman: 8.672941176470589
# Total waktu dalam rata-rata: 36.90705882352942
# Lingkungan: Mapleridge
# Rata-rata waktu respon : 8.993258426966294
# Rata-rata waktu pengiriman: 5.44494382022472
# Total waktu dalam rata-rata: 35.23707865168537
# Lingkungan: Marina District
# Rata-rata waktu respon : 9.05
# Rata-rata waktu pengiriman: 0.75
# Total waktu dalam rata-rata: 17.55
# Lingkungan: Northeast Central District
# Rata-rata waktu respon : 7.795
# Rata-rata waktu pengiriman: 5.35
# Total waktu dalam rata-rata: 23.574999999999996
# Lingkungan: Riverdale
# Rata-rata waktu respon : 4.446153846153846
# Rata-rata waktu pengiriman: -0.12307692307692306
# Total waktu dalam rata-rata: 15.123076923076924
# Lingkungan: Dexter-Fenkell
# Rata-rata waktu respon : 21.20909090909091
# Rata-rata waktu pengiriman: 13.945454545454545
# Total waktu dalam rata-rata: 62.25454545454545
# Lingkungan: Lafayette Park
# Rata-rata waktu respon : 5.7441176470588236
# Rata-rata waktu pengiriman: 3.488235294117647
# Total waktu dalam rata-rata: 32.83823529411764
# Lingkungan: Seven Mile-Rouge
# Rata-rata waktu respon : 7.604999999999999
# Rata-rata waktu pengiriman: 3.25
# Total waktu dalam rata-rata: 37.440000000000005
# Lingkungan: Chadsey Condon
# Rata-rata waktu respon : 11.516666666666667
# Rata-rata waktu pengiriman: 6.430000000000001
# Total waktu dalam rata-rata: 50.79333333333332
# Lingkungan: Weatherby
# Rata-rata waktu respon : 13.811111111111112
# Rata-rata waktu pengiriman: 10.94074074074074
# Total waktu dalam rata-rata: 26.3962962962963
# Lingkungan: Jeffries
# Rata-rata waktu respon : 1.25625
# Rata-rata waktu pengiriman: 0.037500000000000006
# Total waktu dalam rata-rata: 24.1375
# Lingkungan: Mohican Regent
# Rata-rata waktu respon : 5.487500000000001
# Rata-rata waktu pengiriman: 1.56
# Total waktu dalam rata-rata: 21.067500000000003
# Lingkungan: Cultural Center
# Rata-rata waktu respon : 5.644186046511628
# Rata-rata waktu pengiriman: 2.5139534883720933
# Total waktu dalam rata-rata: 32.486046511627904
# Lingkungan: Plymouth-I96
# Rata-rata waktu respon : 5.494736842105263
# Rata-rata waktu pengiriman: 3.1105263157894742
# Total waktu dalam rata-rata: 12.194736842105263
# Lingkungan: University District
# Rata-rata waktu respon : 5.852
# Rata-rata waktu pengiriman: 2.6839999999999997
# Total waktu dalam rata-rata: 21.531999999999996
# Lingkungan: Gratiot-Grand
# Rata-rata waktu respon : 10.011111111111111
# Rata-rata waktu pengiriman: 5.075
# Total waktu dalam rata-rata: 34.205555555555556
# Lingkungan: Schaefer 7/8 Lodge
# Rata-rata waktu respon : 10.909090909090912
# Rata-rata waktu pengiriman: 5.351515151515152
# Total waktu dalam rata-rata: 42.548484848484854
# Lingkungan: Medical Center
# Rata-rata waktu respon : 14.6625
# Rata-rata waktu pengiriman: 9.912499999999998
# Total waktu dalam rata-rata: 49.095000000000006
# Lingkungan: Franklin
# Rata-rata waktu respon : 17.28478260869565
# Rata-rata waktu pengiriman: 13.517391304347825
# Total waktu dalam rata-rata: 32.95869565217391
# Lingkungan: Bagley
# Rata-rata waktu respon : 7.377419354838708
# Rata-rata waktu pengiriman: 6.554838709677419
# Total waktu dalam rata-rata: 23.706451612903226
# Lingkungan: Fox Creek
# Rata-rata waktu respon : 9.095
# Rata-rata waktu pengiriman: 5.405000000000002
# Total waktu dalam rata-rata: 35.1825
# Lingkungan: Winship
# Rata-rata waktu respon : 14.92909090909091
# Rata-rata waktu pengiriman: 8.814545454545454
# Total waktu dalam rata-rata: 45.534545454545444
# Lingkungan: Southfield Plymouth
# Rata-rata waktu respon : 2.1
# Rata-rata waktu pengiriman: 0.30000000000000004
# Total waktu dalam rata-rata: 11.461538461538462
# Lingkungan: Poletown East
# Rata-rata waktu respon : 14.248148148148145
# Rata-rata waktu pengiriman: 5.28888888888889
# Total waktu dalam rata-rata: 42.0111111111111
# Lingkungan: Brush Park
# Rata-rata waktu respon : 9.173170731707318
# Rata-rata waktu pengiriman: 4.8048780487804885
# Total waktu dalam rata-rata: 17.365853658536587
# Lingkungan: Hawthorne Park
# Rata-rata waktu respon : 7.293333333333334
# Rata-rata waktu pengiriman: 6.2700000000000005
# Total waktu dalam rata-rata: 18.503333333333334
# Lingkungan: Moross-Morang
# Rata-rata waktu respon : 17.61509433962264
# Rata-rata waktu pengiriman: 11.962264150943401
# Total waktu dalam rata-rata: 43.764150943396224
# Lingkungan: Plymouth-Hubbell
# Rata-rata waktu respon : 26.98461538461538
# Rata-rata waktu pengiriman: 23.565384615384612
# Total waktu dalam rata-rata: 47.18653846153846
# Lingkungan: Harmony Village
# Rata-rata waktu respon : 14.697674418604654
# Rata-rata waktu pengiriman: 9.830232558139533
# Total waktu dalam rata-rata: 28.723255813953486
# Lingkungan: Sherwood Forest
# Rata-rata waktu respon : 0.3111111111111111
# Rata-rata waktu pengiriman: 0.16666666666666666
# Total waktu dalam rata-rata: 37.65555555555555
# Lingkungan: Hubbell-Lyndon
# Rata-rata waktu respon : 14.98888888888889
# Rata-rata waktu pengiriman: 9.915555555555557
# Total waktu dalam rata-rata: 38.13111111111111
# Lingkungan: Von Steuben
# Rata-rata waktu respon : 11.154285714285713
# Rata-rata waktu pengiriman: 5.659999999999998
# Total waktu dalam rata-rata: 34.12285714285715
# Lingkungan: Morningside
# Rata-rata waktu respon : 18.453448275862065
# Rata-rata waktu pengiriman: 9.291379310344826
# Total waktu dalam rata-rata: 49.406896551724145
# Lingkungan: McDowell
# Rata-rata waktu respon : 16.580000000000002
# Rata-rata waktu pengiriman: 10.33
# Total waktu dalam rata-rata: 37.11
# Lingkungan: East Village
# Rata-rata waktu respon : 19.71521739130435
# Rata-rata waktu pengiriman: 14.828260869565215
# Total waktu dalam rata-rata: 57.00869565217391
# Lingkungan: Denby
# Rata-rata waktu respon : 11.841025641025642
# Rata-rata waktu pengiriman: 7.5538461538461545
# Total waktu dalam rata-rata: 36.435897435897445
# Lingkungan: Oakwood Heights
# Rata-rata waktu respon : 6.833333333333333
# Rata-rata waktu pengiriman: 2.733333333333333
# Total waktu dalam rata-rata: 28.599999999999998
# Lingkungan: Outer Drive-Hayes
# Rata-rata waktu respon : 10.023762376237622
# Rata-rata waktu pengiriman: 5.480198019801979
# Total waktu dalam rata-rata: 31.98118811881188
# Lingkungan: Fitzgerald/Marygrove
# Rata-rata waktu respon : 15.023333333333335
# Rata-rata waktu pengiriman: 8.81333333333333
# Total waktu dalam rata-rata: 43.43333333333333
# Lingkungan: Greenfield-Grand River
# Rata-rata waktu respon : 8.888235294117647
# Rata-rata waktu pengiriman: 5.476470588235294
# Total waktu dalam rata-rata: 43.01764705882353
# Lingkungan: Medbury Park
# Rata-rata waktu respon : 2.175
# Rata-rata waktu pengiriman: 0.15
# Total waktu dalam rata-rata: 11.4125
# Lingkungan: Wade
# Rata-rata waktu respon : 16.30769230769231
# Rata-rata waktu pengiriman: 11.569230769230767
# Total waktu dalam rata-rata: 28.138461538461538
# Lingkungan: Cadillac Heights
# Rata-rata waktu respon : 7.175
# Rata-rata waktu pengiriman: 2.5000000000000004
# Total waktu dalam rata-rata: 34.787499999999994
# Lingkungan: Garden Homes
# Rata-rata waktu respon : 19.527272727272727
# Rata-rata waktu pengiriman: 15.42727272727273
# Total waktu dalam rata-rata: 31.172727272727272
# Lingkungan: Pilgrim Village
# Rata-rata waktu respon : 18.0
# Rata-rata waktu pengiriman: 12.131818181818181
# Total waktu dalam rata-rata: 32.81363636363637
# Lingkungan: West Village
# Rata-rata waktu respon : 30.0
# Rata-rata waktu pengiriman: 20.1
# Total waktu dalam rata-rata: 75.25
# Lingkungan: Springwells
# Rata-rata waktu respon : 12.443902439024388
# Rata-rata waktu pengiriman: 6.084146341463415
# Total waktu dalam rata-rata: 30.73536585365854
# Lingkungan: Chalfonte
# Rata-rata waktu respon : 19.426086956521736
# Rata-rata waktu pengiriman: 13.643478260869566
# Total waktu dalam rata-rata: 34.06956521739131
# Lingkungan: Martin Park
# Rata-rata waktu respon : 14.833333333333334
# Rata-rata waktu pengiriman: 9.75
# Total waktu dalam rata-rata: 50.79166666666668
# Lingkungan: Jefferson Chalmers
# Rata-rata waktu respon : 9.202564102564104
# Rata-rata waktu pengiriman: 4.37948717948718
# Total waktu dalam rata-rata: 32.800000000000004
# Lingkungan: Grand River-St Marys
# Rata-rata waktu respon : 16.080000000000002
# Rata-rata waktu pengiriman: 9.686666666666667
# Total waktu dalam rata-rata: 52.75999999999999
# Lingkungan: Greenfield Park
# Rata-rata waktu respon : 7.971111111111112
# Rata-rata waktu pengiriman: 5.20888888888889
# Total waktu dalam rata-rata: 25.924444444444447
# Lingkungan: Jamison
# Rata-rata waktu respon : 49.74285714285713
# Rata-rata waktu pengiriman: 32.728571428571435
# Total waktu dalam rata-rata: 97.38571428571429
# Lingkungan: Holcomb Community
# Rata-rata waktu respon : 6.291463414634146
# Rata-rata waktu pengiriman: 3.730487804878049
# Total waktu dalam rata-rata: 22.203658536585362
# Lingkungan: Conner Creek Industrial
# Rata-rata waktu respon : 16.29444444444444
# Rata-rata waktu pengiriman: 10.850000000000001
# Total waktu dalam rata-rata: 44.06666666666666
# Lingkungan: Eliza Howell
# Rata-rata waktu respon : 32.827777777777776
# Rata-rata waktu pengiriman: 23.416666666666664
# Total waktu dalam rata-rata: 47.455555555555556
# Lingkungan: Chandler Park-Chalmers
# Rata-rata waktu respon : 7.485714285714287
# Rata-rata waktu pengiriman: 5.035714285714286
# Total waktu dalam rata-rata: 26.535714285714285
# Lingkungan: Henry Ford
# Rata-rata waktu respon : 22.4
# Rata-rata waktu pengiriman: 15.222222222222221
# Total waktu dalam rata-rata: 40.488888888888894
# Lingkungan: East English Village
# Rata-rata waktu respon : 10.403125
# Rata-rata waktu pengiriman: 9.884374999999999
# Total waktu dalam rata-rata: 29.762500000000003
# Lingkungan: Yorkshire Woods
# Rata-rata waktu respon : 13.293750000000001
# Rata-rata waktu pengiriman: 9.175
# Total waktu dalam rata-rata: 58.065625000000004
# Lingkungan: Elijah McCoy
# Rata-rata waktu respon : 9.440000000000001
# Rata-rata waktu pengiriman: 3.4066666666666667
# Total waktu dalam rata-rata: 63.29333333333332
# Lingkungan: Rivertown
# Rata-rata waktu respon : 2.54468085106383
# Rata-rata waktu pengiriman: 1.225531914893617
# Total waktu dalam rata-rata: 20.87446808510638
# Lingkungan: North Campau
# Rata-rata waktu respon : 4.044444444444444
# Rata-rata waktu pengiriman: 2.488888888888889
# Total waktu dalam rata-rata: 26.585185185185182
# Lingkungan: South of Six
# Rata-rata waktu respon : 4.377777777777778
# Rata-rata waktu pengiriman: 0.7777777777777777
# Total waktu dalam rata-rata: 35.87777777777778
# Lingkungan: Midwest
# Rata-rata waktu respon : 14.38181818181818
# Rata-rata waktu pengiriman: 6.339999999999999
# Total waktu dalam rata-rata: 37.227272727272734
# Lingkungan: Northwest Community
# Rata-rata waktu respon : 3.325
# Rata-rata waktu pengiriman: 0.225
# Total waktu dalam rata-rata: 18.0625
# Lingkungan: Gold Coast
# Rata-rata waktu respon : 23.890000000000004
# Rata-rata waktu pengiriman: 23.01
# Total waktu dalam rata-rata: 51.06999999999999
# Lingkungan: Littlefield Community
# Rata-rata waktu respon : 6.6000000000000005
# Rata-rata waktu pengiriman: 1.9545454545454541
# Total waktu dalam rata-rata: 37.58181818181818
# Lingkungan: San Bernardo
# Rata-rata waktu respon : 21.185714285714287
# Rata-rata waktu pengiriman: 16.357142857142858
# Total waktu dalam rata-rata: 27.271428571428572
# Lingkungan: Butler
# Rata-rata waktu respon : 16.742105263157892
# Rata-rata waktu pengiriman: 14.378947368421056
# Total waktu dalam rata-rata: 28.2
# Lingkungan: New Center Commons
# Rata-rata waktu respon : 4.4875
# Rata-rata waktu pengiriman: 0.7125
# Total waktu dalam rata-rata: 24.6125
# Lingkungan: Fiskhorn
# Rata-rata waktu respon : 15.709523809523809
# Rata-rata waktu pengiriman: 9.657142857142855
# Total waktu dalam rata-rata: 47.095238095238095
# Lingkungan: Rouge Park
# Rata-rata waktu respon : 2.7125
# Rata-rata waktu pengiriman: 0.825
# Total waktu dalam rata-rata: 12.350000000000001
# Lingkungan: Herman Kiefer
# Rata-rata waktu respon : 23.949999999999996
# Rata-rata waktu pengiriman: 11.85
# Total waktu dalam rata-rata: 35.875
# Lingkungan: Blackstone Park
# Rata-rata waktu respon : 14.13
# Rata-rata waktu pengiriman: 8.379999999999999
# Total waktu dalam rata-rata: 22.81
# Lingkungan: Davison-Schoolcraft
# Rata-rata waktu respon : 8.53076923076923
# Rata-rata waktu pengiriman: 2.9538461538461545
# Total waktu dalam rata-rata: 66.03076923076922
# Lingkungan: Mexicantown
# Rata-rata waktu respon : 4.0
# Rata-rata waktu pengiriman: 1.2333333333333334
# Total waktu dalam rata-rata: 14.433333333333335
# Lingkungan: Gratiot Woods
# Rata-rata waktu respon : 36.07857142857143
# Rata-rata waktu pengiriman: 31.95
# Total waktu dalam rata-rata: 85.07142857142858
# Lingkungan: State Fair
# Rata-rata waktu respon : 4.637499999999999
# Rata-rata waktu pengiriman: -0.7250000000000001
# Total waktu dalam rata-rata: 71.6
# Lingkungan: Joseph Berry Sub
# Rata-rata waktu respon : 0.0
# Rata-rata waktu pengiriman: 2.525
# Total waktu dalam rata-rata: 8.225
# Lingkungan: Melvern Hill
# Rata-rata waktu respon : 1.525
# Rata-rata waktu pengiriman: 1.05
# Total waktu dalam rata-rata: 71.225
# Lingkungan: Pride Area Community
# Rata-rata waktu respon : 9.933333333333332
# Rata-rata waktu pengiriman: 7.6000000000000005
# Total waktu dalam rata-rata: 21.833333333333332
# Lingkungan: Penrose
# Rata-rata waktu respon : 6.9142857142857155
# Rata-rata waktu pengiriman: -0.0857142857142857
# Total waktu dalam rata-rata: 23.085714285714285
# Lingkungan: Sherwood
# Rata-rata waktu respon : 6.2700000000000005
# Rata-rata waktu pengiriman: 0.74
# Total waktu dalam rata-rata: 46.17
# Lingkungan: Michigan-Martin
# Rata-rata waktu respon : 2.3200000000000003
# Rata-rata waktu pengiriman: 0.18
# Total waktu dalam rata-rata: 7.859999999999999
# Lingkungan: Virginia Park
# Rata-rata waktu respon : 13.066666666666668
# Rata-rata waktu pengiriman: 9.299999999999999
# Total waktu dalam rata-rata: 39.06666666666666
# Lingkungan: Wildemere Park
# Rata-rata waktu respon : 37.81666666666667
# Rata-rata waktu pengiriman: 32.23333333333334
# Total waktu dalam rata-rata: 109.06666666666668
# Lingkungan: West Outer Drive
# Rata-rata waktu respon : 11.0
# Rata-rata waktu pengiriman: 8.233333333333333
# Total waktu dalam rata-rata: 40.083333333333336
# Lingkungan: Grixdale Farms
# Rata-rata waktu respon : 6.975
# Rata-rata waktu pengiriman: 3.3200000000000003
# Total waktu dalam rata-rata: 23.259999999999998
# Lingkungan: Berg-Lahser
# Rata-rata waktu respon : 29.178571428571427
# Rata-rata waktu pengiriman: 17.6
# Total waktu dalam rata-rata: 45.17857142857143
# Lingkungan: Arden Park
# Rata-rata waktu respon : 0.0
# Rata-rata waktu pengiriman: 0.0
# Total waktu dalam rata-rata: 19.4
# Lingkungan: Pingree Park
# Rata-rata waktu respon : 2.7
# Rata-rata waktu pengiriman: 2.025
# Total waktu dalam rata-rata: 55.525
# Lingkungan: Green Acres
# Rata-rata waktu respon : 4.0
# Rata-rata waktu pengiriman: 1.5875000000000001
# Total waktu dalam rata-rata: 31.65
# Lingkungan: Brewster Homes
# Rata-rata waktu respon : 13.175
# Rata-rata waktu pengiriman: 4.775
# Total waktu dalam rata-rata: 41.7625
# Lingkungan: Tri-Point
# Rata-rata waktu respon : 3.4333333333333336
# Rata-rata waktu pengiriman: 0.6
# Total waktu dalam rata-rata: 25.966666666666665
# Lingkungan: Garden View
# Rata-rata waktu respon : 17.476923076923075
# Rata-rata waktu pengiriman: 11.892307692307693
# Total waktu dalam rata-rata: 57.43846153846154
# Lingkungan: Boston Edison
# Rata-rata waktu respon : 30.066666666666666
# Rata-rata waktu pengiriman: 9.700000000000001
# Total waktu dalam rata-rata: 76.26666666666667
# Lingkungan: East Canfield
# Rata-rata waktu respon : 0.0
# Rata-rata waktu pengiriman: 2.0
# Total waktu dalam rata-rata: 3.35
# Lingkungan: Paveway
# Rata-rata waktu respon : 7.075
# Rata-rata waktu pengiriman: 0.7749999999999999
# Total waktu dalam rata-rata: 20.75
# Lingkungan: LaSalle College Park
# Rata-rata waktu respon : 25.00909090909091
# Rata-rata waktu pengiriman: 21.072727272727274
# Total waktu dalam rata-rata: 55.65454545454545
# Lingkungan: Happy Homes
# Rata-rata waktu respon : 12.95
# Rata-rata waktu pengiriman: 6.15
# Total waktu dalam rata-rata: 61.7
# Lingkungan: Gateway Community
# Rata-rata waktu respon : 8.755555555555555
# Rata-rata waktu pengiriman: 1.7777777777777777
# Total waktu dalam rata-rata: 29.22222222222222
# Lingkungan: Hubbard Richard
# Rata-rata waktu respon : 5.25
# Rata-rata waktu pengiriman: 0.75
# Total waktu dalam rata-rata: 45.65
# Lingkungan: Seven Mile Lodge
# Rata-rata waktu respon : 13.85
# Rata-rata waktu pengiriman: 2.1
# Total waktu dalam rata-rata: 38.2
# Lingkungan: West Virginia Park
# Rata-rata waktu respon : 0.0
# Rata-rata waktu pengiriman: 0.0
# Total waktu dalam rata-rata: 0.5
# Lingkungan: Greenwich
# Rata-rata waktu respon : 10.1
# Rata-rata waktu pengiriman: 1.44
# Total waktu dalam rata-rata: 32.00000000000001
# Lingkungan: LaSalle Gardens
# Rata-rata waktu respon : 43.8
# Rata-rata waktu pengiriman: 29.28
# Total waktu dalam rata-rata: 96.67999999999999
# Lingkungan: Old Redford
# Rata-rata waktu respon : 1.8166666666666667
# Rata-rata waktu pengiriman: 0.0
# Total waktu dalam rata-rata: 25.933333333333334
# Lingkungan: Belle Isle
# Rata-rata waktu respon : 0.0
# Rata-rata waktu pengiriman: 0.0
# Total waktu dalam rata-rata: 8.5
# Lingkungan: Carbon Works
# Rata-rata waktu respon : 13.05
# Rata-rata waktu pengiriman: 1.25
# Total waktu dalam rata-rata: 65.2
# Lingkungan: Russell Industrial
# Rata-rata waktu respon : 26.6
# Rata-rata waktu pengiriman: 18.4
# Total waktu dalam rata-rata: 106.7
# Lingkungan: Douglass
# Rata-rata waktu respon : 37.55
# Rata-rata waktu pengiriman: 32.1
# Total waktu dalam rata-rata: 89.14999999999999
# Lingkungan: Historic Atkinson
# Rata-rata waktu respon : 18.35
# Rata-rata waktu pengiriman: 10.9
# Total waktu dalam rata-rata: 49.599999999999994
# Lingkungan: Fitzgerald
# Rata-rata waktu respon : 63.9
# Rata-rata waktu pengiriman: 34.5
# Total waktu dalam rata-rata: 99.6
# Lingkungan: All Detroit
# Rata-rata waktu respon : 9.40852188883424
# Rata-rata waktu pengiriman: 5.641662567634036
# Total waktu dalam rata-rata: 31.09880718150527

# %%
import json

output_file = 'neighborhood_stats.json'
with open(output_file, 'w') as json_file:
    json.dump(neighborhood_stats, json_file, indent=4)

print(f"File JSON '{output_file}' telah berhasil dibuat.")
# Out:
# File JSON 'neighborhood_stats.json' telah berhasil dibuat.
